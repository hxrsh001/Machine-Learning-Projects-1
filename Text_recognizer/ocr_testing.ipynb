# %% [markdown]
# ### EasyOcr Documention <br>
# <a href="https://www.jaided.ai/easyocr/tutorial/">Documentation Link</a>

# %%
import easyocr
from PIL import Image

# %%
#first time it will download the models, for detection
reader = easyocr.Reader(['hi', 'en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
result = reader.readtext('img2.jpeg')
result 
# text with bounding box cordinates and confidence score
# Out:
# c:\Users\GOLU\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# [([[np.int32(39), np.int32(19)],
#    [np.int32(107), np.int32(19)],
#    [np.int32(107), np.int32(39)],
#    [np.int32(39), np.int32(39)]],
#   'YOU ARE',
#   np.float64(0.9915913237215929)),
#  ([[np.int32(24), np.int32(40)],
#    [np.int32(118), np.int32(40)],
#    [np.int32(118), np.int32(64)],
#    [np.int32(24), np.int32(64)]],
#   'STRONGER',
#   np.float64(0.9999314682516105)),
#  ([[np.int32(35), np.int32(65)],
#    [np.int32(111), np.int32(65)],
#    [np.int32(111), np.int32(85)],
#    [np.int32(35), np.int32(85)]],
#   'THAN YOU',
#   np.float64(0.7017916799635423)),
#  ([[np.int32(44), np.int32(84)],
#    [np.int32(100), np.int32(84)],
#    [np.int32(100), np.int32(108)],
#    [np.int32(44), np.int32(108)]],
#   'THINK',
#   np.float64(0.9553365866392356))]

# %%
# to get actuall information, that you want 
result = reader.readtext('img2.jpeg',detail=0)
print(result)
print(" ".join(result))
# Out:
# c:\Users\GOLU\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# ['YOU ARE', 'STRONGER', 'THAN YOU', 'THINK']
# YOU ARE STRONGER THAN YOU THINK

# %%
## pillow object 
img = Image.open('img3.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x148>

# %%
# passed img object to ocr 
reader.readtext(img,detail=0)
# Out:
# ['Tne',
#  'best',
#  'Preparation',
#  'tor   tonorrow',
#  'is',
#  'doing your',
#  'best  today']

# %%
## you can pass the data as a byte 
with open('img2.jpeg','rb') as file :
    image_data = file.read()

    result = reader.readtext(image_data,detail=0) 
    print(" ".join(result))
# Out:
# YOU ARE STRONGER THAN YOU THINK
